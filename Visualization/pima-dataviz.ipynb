# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import os

# %%
df = pd.read_csv("C:/Users/parthenia/Desktop/MLDAYS/Visualization/datasets_228_482_diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df["Overweight"] = [1 if x > 25 else 0 for x in df.BMI]
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Overweight
# 0                     0.627   50        1           1
# 1                     0.351   31        0           1
# 2                     0.672   32        1           0
# 3                     0.167   21        0           1
# 4                     2.288   33        1           1

# %% [markdown]
# # Relational Plots with Matplotlib
# * **Scatter plot:** iki değişken arasındaki ilişkinin dağılımını gösterir.
# * **Lineplot:** İki değişken arasındaki ilişkiyi sürekli gösterir. (Zaman serilerinde kullanılır)
# * **s parametresi:** marker boyutu
# * **c parametresi:** marker rengi, hangi değişkeni tuttuğu da yazılabilir
# * **alpha:** marker opaklığı

# %%
plt.rcParams.update({'font.size': 25})

# %%
sns.set_context("paper")

# %%
plt.scatter(df.Age, df.Insulin, c=df.Overweight, s=389,
            alpha=0.2, cmap="viridis") #cmap renk paleti
plt.colorbar(); #hangi rengin hangi değere denk geldiğini gösteren yandaki ölçek
plt.xlabel("Age") #eksen ismi
plt.ylabel("Insulin") 
plt.title("Relationship between Age and Insulin") #plot ismi
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-342697c2f4a7> in <module>
# ----> 1 plt.scatter(df.Age, df.Insulin, c=df.Overweight, s=389,
#       2             alpha=0.2, cmap="viridis") #cmap renk paleti
#       3 plt.colorbar(); #hangi rengin hangi değere denk geldiğini gösteren yandaki ölçek
#       4 plt.xlabel("Age") #eksen ismi
#       5 plt.ylabel("Insulin")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Overweight'

# %% [markdown]
# # Scatter plot with Subplots
# * **fig, ax = plt.subplots():** figure ve axes object oluşturur. figure’de her şey var, axes data’yı tutuyor.

# %%
fig, ax = plt.subplots()
ax.scatter(df.Age, df.Insulin, c=df.Overweight, cmap="viridis")
ax.set_xlabel("Age")
ax.set_ylabel("Insulin")
ax.set_title("Relationship between Age and Insulin")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-89e2d6e11a59> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(df.Age, df.Insulin, c=df.Overweight, cmap="viridis")
#       3 ax.set_xlabel("Age")
#       4 ax.set_ylabel("Insulin")
#       5 ax.set_title("Relationship between Age and Insulin")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Overweight'

# %% [markdown]
# * **Histogram:** Numerik ya da kategorik verilerde dağılımı yorumlamamıza yardımcı olur.

# %%
fig, ax = plt.subplots()
ax.hist(df.Age, label="Age", bins=5)
ax.set_xlabel("Age")
ax.set_ylabel("Number of Observations")
plt.show()

# %%
fig, ax = plt.subplots(2,1)
plt.show() #show metodu ile gösterilir. boş olmasının nedeni bir veri girilmediğinden

# %%
bins=[20, 30, 40, 50, 60, 70, 80]
fig, ax = plt.subplots()
ax.hist(df.Age, label="Age Bins", bins=bins)
ax.set_xlabel("Age")
ax.set_ylabel("Number of Observations")
plt.show()

# %% [markdown]
# **Bar plot:** Kategorik verinin özelliklerine bakmamızı sağlar.

# %%
fig, ax = plt.subplots()
ax.bar(df.Outcome, df.Insulin)
ax.set_xlabel("Outcome")
ax.set_ylabel("Insulin")
plt.show()

# %% [markdown]
# # Kaydetme

# %%
fig, ax = plt.subplots()
ax.bar(df.Age, df.Insulin)
ax.set_xticklabels(df.Age, rotation=90)
fig.savefig("Age.png")

# %% [markdown]
# * **fig.savefig(“Age.png”):** kayıp olmadan kaydeder, yüksek kalitelidir ama çok hafıza tutar.
# * **fig.savefig(“Age.jpg”, quality=50):** websitesine konulabilir.
# * **fig.savefig(“Age.png”, dpi=200):** dots per inch, dense rendering.
# * **fig.set_size_inches([5,3]):** aspect ratio

# %% [markdown]
# # Seaborn
# * FacetGrid (relplot(), catplot()) subplotlar oluşturabilir
# * AxesSubplot(scatterplot, countplot) bir tane plot oluşturur

# %% [markdown]
# # Count Plot

# %%
sns.set_palette("RdBu")
sns.countplot(x="Age", data=df)
plt.show()

# %%
sns.catplot(x="Age", aspect=3, data=df, kind="count")
plt.show()

# %%
g = sns.catplot(x="Age", aspect=3, data=df, kind="count")
g.fig.suptitle("Age Counts", y=1.04) #ismi yukarı çıkarıyor
plt.show()

# %%
g = sns.catplot(x="Age", aspect=3, data=df, kind="count")
plt.xticks(rotation=30) #labellerin yörüngesi
plt.show()

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x="Age", y="Insulin",data=df, hue="Outcome")
plt.show()

# %%
sns.relplot(x="Age", y="Insulin",data=df, hue="Outcome", #hue parametresinde lejant ile birlikte geliyor
            kind="scatter")
plt.show()

# %% [markdown]
# # Line plot

# %%
sns.relplot(x="Age", y="Insulin", data=df, kind="line", ci="sd", markers=True, dashes=False)
plt.show()

# %%
sns.relplot(x="Age", y="Insulin", data=df, kind="line", aspect=4, ci="sd")
plt.show()

# %%
sns.relplot(x="Age", y="Insulin", data=df, kind="line", aspect=4, ci=None)
plt.show()

# %%
sns.relplot(x="Insulin", y="Glucose", data=df, kind="scatter", col="Outcome")
plt.show()

# %%
sns.relplot(x="Insulin", y="Glucose", data=df, kind="scatter", col="Outcome", row="Overweight")
plt.show()

# %% [markdown]
# # Heatmap

# %%
sns.set_palette("RdBu")
correlation=df.corr()
sns.heatmap(correlation, annot=True) #annot=true korelasyondaki değerleri üzerine yazdırır.
plt.show()

# %% [markdown]
# # Categorical Plots

# %%
sns.catplot(x="Outcome",y="Insulin",data=df, kind="bar")
plt.show()

# %%
sns.catplot(x="Outcome",y="Age",data=df, kind="box")
plt.show()

# %%
sns.catplot(x="Outcome",data=df, kind="count")
plt.show()

# %% [markdown]
# # Presets

# %%
sns.set_style("dark")
sns.catplot(x="Outcome",data=df, kind="count")
plt.show()
## white, dark, whitegrid, darkgrid, ticks

# %%
sns.set_palette("PRGn") #veri markerının rengini değiştirmek için 
sns.catplot(x="Outcome",data=df, kind="count")
plt.show()
# categorical plotlarda “RdBu”, “PRGn”,”RdBu_r”,”PRGn_r”
# continuous plotlarda Greys, Blues, PuRd, GnBu

# %%
sns.set_context("paper")
plt.show()
# paper,poster, talk
